# %%
import pandas as pd

# %%
# Criando um dicionario 
vendas  = {
    'data':['22/05/2026','23/05/2026'],
    'valor':[500,300],
    'produto':['arroz','feijao'],
    'quantidade':[50,70]    
}

# Transformando meu dicionario venda em um data frame
vendas_df = pd.DataFrame(vendas)

# %%
vendas_df
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# ...

# %% [markdown]
# # Importando uma base de dados

# %%
# Lendo uma base de dados externa
vendas_df = pd.read_excel('Vendas.xlsx')

# %%
# head() exibe as primeiras linhas 
# tail exibe as ultimas linhas
vendas_df.head(3)
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
#
#    Valor Unitário  Valor Final
# 0             358          358
# 1             180          360
# 2             368          368

# %%
#shape retorna a quantidade de linhas e de colunas (linhas,colunas)
vendas_df.shape
# Out:
# (93910, 7)

# %%
# print(vendas_df.describe())
# Out:
#        Código Venda                           Data    Quantidade  \
# count  93910.000000                          93910  93910.000000
# mean   32464.762155  2019-06-16 23:52:28.265360896      2.166553
# min        1.000000            2019-01-01 00:00:00      1.000000
# 25%    16204.000000            2019-03-26 00:00:00      1.000000
# 50%    32367.000000            2019-06-17 00:00:00      2.000000
# 75%    48793.750000            2019-09-08 00:00:00      3.000000
# max    65014.000000            2019-11-30 00:00:00      5.000000
# std    18809.007093                            NaN      1.258732
#
#        Valor Unitário   Valor Final
# count    93910.000000  93910.000000
# mean       191.725886    414.862656
# min         30.000000     30.000000
# 25%        100.000000    156.000000
# 50%        155.000000    274.000000
# 75%        248.000000    524.000000
# max        750.000000   3750.000000
# std        145.215519    434.846228

# %% [markdown]
# # Metodos para manipular meu data frame

# %%
# Acessando duas colunas do meu data frame original vendas_df
# o resultado é um data frame tambem 
df_teste = vendas_df[['Produto','Quantidade']]
type(df_teste)
# Out:
# pandas.core.frame.DataFrame

# %%
# Caso eu selecione somente uma coluna do meu data frame o resultado e uma series do pandas
produtos = vendas_df['Produto']
type(produtos)
# Out:
# pandas.core.series.Series

# %%
vendas_df.head(5)
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
# 3             2 2019-01-02      Norte Shopping         Relógio           3
# 4             2 2019-01-02      Norte Shopping    Chinelo Liso           1
#
#    Valor Unitário  Valor Final
# 0             358          358
# 1             180          360
# 2             368          368
# 3             200          600
# 4              71           71

# %%
# loc() && iloc

# Pegar somente a primeira linha 
# display(vendas_df.loc(1))


# Pegar da primeira linha ate a quinta  linha 
display(vendas_df.loc[0:4])
# Out:
#    Código Venda       Data             ID Loja         Produto  Quantidade  \
# 0             1 2019-01-01  Iguatemi Esplanada  Sapato Estampa           1
# 1             1 2019-01-01  Iguatemi Esplanada        Camiseta           2
# 2             1 2019-01-01  Iguatemi Esplanada   Sapato Xadrez           1
# 3             2 2019-01-02      Norte Shopping         Relógio           3
# 4             2 2019-01-02      Norte Shopping    Chinelo Liso           1
#
#    Valor Unitário  Valor Final
# 0             358          358
# 1             180          360
# 2             368          368
# 3             200          600
# 4              71           71

# %%
# Pegar linhas que correspondem a uma determinada condicao
vendas_norte_shopping_df = vendas_df.loc[  vendas_df['ID Loja'] == 'Norte Shopping' ]
# Pegar varias linhas e varias colunas usando o loc
# loc(linhas,colunas)
# Filtrando linhas e colunas
vendas_df.loc[  vendas_df['ID Loja'] == 'Norte Shopping' , ['ID Loja','Produto','Quantidade'] ]
# Out:
#               ID Loja                 Produto  Quantidade
# 3      Norte Shopping                 Relógio           3
# 4      Norte Shopping            Chinelo Liso           1
# 8      Norte Shopping  Camisa Gola V Listrado           1
# 9      Norte Shopping             Camisa Liso           1
# 100    Norte Shopping            Cueca Xadrez           5
# ...               ...                     ...         ...
# 93716  Norte Shopping             Polo Xadrez           1
# 93754  Norte Shopping              Calça Liso           1
# 93755  Norte Shopping          Casaco Estampa           2
# 93756  Norte Shopping                   Gorro           2
# 93852  Norte Shopping           Bermuda Linho           1
#
# [3924 rows x 3 columns]

# %% [markdown]
# # Adicionando colunas

# %%
# A partir de uma coluna que existe

# vendas_df['Comissao'] = vendas_df['Valor Final'] * 0.05


# Criando uma coluna com valor padrao
# interessante entender o metodo loc(LINHAS,COLUNAS)

vendas_df.loc[ : ,'Imposto'] = 0
vendas_df.head(10)
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final  Comissao  \
# 0          Sapato Estampa           1             358          358     17.90
# 1                Camiseta           2             180          360     18.00
# 2           Sapato Xadrez           1             368          368     18.40
# ...

# %%
# Vendas de dezembro que faltavam
vendas_dez_df = pd.read_excel('Vendas - Dez.xlsx')
vendas_dez_df
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
vendas_df = pd.concat([vendas_df, vendas_dez_df], ignore_index=True)
vendas_df
# Out:
#         Código Venda       Data                     ID Loja           Produto  \
# 0                  1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                  1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                  1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                  2 2019-01-02              Norte Shopping           Relógio
# 4                  2 2019-01-02              Norte Shopping      Chinelo Liso
# ...              ...        ...                         ...               ...
# 115172         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 115173         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 115174         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 115175         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 115176         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
# ...
